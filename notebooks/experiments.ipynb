# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/liga_mx_raw.csv')

# %%
df
# Out:
#                   week  day        date   time  home_team  xgh score  xga  \
# 0                    1  Sat  2019-07-20  17:00    Pachuca  2.8   1–3  1.8
# 1                    1  Sat  2019-07-20  17:00   Atlético  1.4   0–2  2.2
# 2                    1  Fri  2019-07-19  19:00     Puebla  1.1   1–3  1.4
# 3                    1  Fri  2019-07-19  21:00      Atlas  1.0   1–0  1.5
# 4                    1  Sun  2019-07-21  12:00     Toluca  0.7   0–2  1.5
# ...                ...  ...         ...    ...        ...  ...   ...  ...
# 1702     Semifinal Ida  Thu  2024-05-16  22:00  Monterrey  0.7   0–1  0.6
# 1703  Semifinal Vuelta  Sat  2024-05-18  21:00    América  1.0   1–0  0.6
# 1704  Semifinal Vuelta  Sun  2024-05-19  19:00  Cruz Azul  1.7   1–2  2.5
# 1705         Final Ida  Thu  2024-05-23  21:00  Cruz Azul  1.2   1–1  2.3
# 1706      Final Vuelta  Sun  2024-05-26  20:00    América  1.6   1–0  1.3
#
#         away_team attendance                                 venue  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1707 entries, 0 to 1706
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   week              1677 non-null   object
#  1   day               1707 non-null   object
#  2   date              1707 non-null   object
#  3   time              1707 non-null   object
#  4   home_team         1707 non-null   object
#  5   xgh               1642 non-null   object
#  6   score             1644 non-null   object
#  7   xga               1642 non-null   object
#  8   away_team         1707 non-null   object
#  9   attendance        1278 non-null   object
#  10  venue             1707 non-null   object
#  11  referee           1643 non-null   object
#  12  match_report_url  1704 non-null   object
#  13  season_type       1364 non-null   object
#  14  season_year       1364 non-null   float64
#  15  seeason_phase     1707 non-null   object
# ...

# %%
df['date'][206:209]
# Out:
# 206    2020-01-25
# 207    2020-01-25
# 208    2020-01-25
# Name: date, dtype: object

# %%
# df['date'] = pd.to_datetime(df['date'])

pd.to_datetime(df['date'][205:209])
# Out:
# 205   2020-01-26
# 206   2020-01-25
# 207   2020-01-25
# 208   2020-01-25
# Name: date, dtype: datetime64[ns]

# %%
c = 0
for r in df['date']:
    c+=1
    try:
        pd.to_datetime(r)
    except ValueError as e:
        print(r, c)
        raise e
# Out:
# Date 517
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# Cell In[16], line 8
#       6 except ValueError as e:
#       7     print(r, c)
# ----> 8     raise e
#
# Cell In[16], line 5
#       3 c+=1
#       4 try:
# ----> 5     pd.to_datetime(r)
#       6 except ValueError as e:
#       7     print(r, c)
#
# File ~/Documents/match-predictor/venv/lib/python3.13/site-packages/pandas/core/tools/datetimes.py:1106, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1104         result = convert_listlike(argc, format)
#    1105 else:
# -> 1106     result = convert_listlike(np.array([arg]), format)[0]
#    1107     if isinstance(arg, bool) and isinstance(result, np.bool_):
#    1108         result = bool(result)  # TODO: avoid this kludge.
#
# ...
